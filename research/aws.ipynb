# %%
import boto3
import os

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
AWS_ACCESS_KEY = os.environ.get('AWS_ACCESS_KEY')
AWS_SECRET_ACCESS_KEY = os.environ.get('AWS_SECRET_ACCESS_KEY')

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='ap-south-1',
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# bloodcancerimages
# elasticbeanstalk-ap-south-1-663198008749

# %%
client = boto3.client('s3',
                      aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

# %%
objects = client.list_objects(Bucket='bloodcancerimages')

# %%
objects['Contents']
# Out:
# [{'Key': 'Benign/WBC-Benign-001.jpg',
#   'LastModified': datetime.datetime(2023, 10, 17, 15, 37, 4, tzinfo=tzutc()),
#   'ETag': '"cd0eb0025ecd82e749d816b7a5f2c20d"',
#   'Size': 19232,
#   'StorageClass': 'STANDARD',
#   'Owner': {'ID': 'c13fb002fd3b9970f460ad358672a60a65326704c525deca85b7c7f121d5d572'}},
#  {'Key': 'Benign/WBC-Benign-002.jpg',
#   'LastModified': datetime.datetime(2023, 10, 17, 15, 37, 5, tzinfo=tzutc()),
#   'ETag': '"c6d4a2eabc72ab98461f410b5f745600"',
#   'Size': 26135,
#   'StorageClass': 'STANDARD',
#   'Owner': {'ID': 'c13fb002fd3b9970f460ad358672a60a65326704c525deca85b7c7f121d5d572'}},
#  {'Key': 'Benign/WBC-Benign-003.jpg',
#   'LastModified': datetime.datetime(2023, 10, 17, 15, 37, 5, tzinfo=tzutc()),
#   'ETag': '"97baed553c4d6ef677dd01164d6e8737"',
#   'Size': 27268,
#   'StorageClass': 'STANDARD',
#   'Owner': {'ID': 'c13fb002fd3b9970f460ad358672a60a65326704c525deca85b7c7f121d5d572'}},
#  {'Key': 'Benign/WBC-Benign-004.jpg',
# ...

# %%
os.getcwd()
# Out:
# 'c:\\Users\\arham\\Acute Lymphoblastic Leukemia\\research'

# %%
file = objects['Contents']

# %%
len(file)
# Out:
# 1000

# %%
downloadFilePath = os.path.join('images', 'Benign')

# %%
local_directory = 'images'
downloadFilePath = os.path.join(local_directory, 'Test.png')

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='ap-south-1',
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

# %%
directory = os.path.join('..', 'images', 'Benign')

# %%
directory
# Out:
# '..\\images\\Benign'

# %%
os.path.join(directory, 'WBC-Benign-002.jpg')
# Out:
# '..\\images\\Benign\\WBC-Benign-002.jpg'

# %%
filePath = os.path.join(directory, 'WBC-Benign-002.jpg')
s3.Bucket('bloodcancerimages').download_file(
    Key='Benign/WBC-Benign-002.jpg', 
    Filename=filePath
    )

# %%
client = boto3.client('s3',
                      aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY)

# %%
files = client.list_objects(Bucket='bloodcancerimages')

# %%
list(s3.Bucket('bloodcancerimages').objects.all())[0].keys
# Out:
# 'Benign/WBC-Benign-001.jpg'

# %%
'Benign/WBC-Benign-001.jpg'.split('/')[1]
# Out:
# 'WBC-Benign-001.jpg'

# %%
images = list(s3.Bucket('bloodcancerimages').objects.all())

# %%
images[2500].key
# Out:
# 'Pro/WBC-Malignant-Pro-049.jpg'

# %%
for image in images:
    key = image.key
    
    dir = key.split('/')
    folder = dir[0]
    file = dir[1]

    downloadPath = os.path.join('..', 'images', folder, file)
    s3.Bucket('bloodcancerimages').download_file(
    Key=key, 
    Filename=downloadPath
    )
